# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from math import floor
from pprint import pprint

# %%
fred_file = Path("../output_data/fred_data.csv")
fred_data = pd.read_csv(fred_file)
fred_data
# Out:
#     Year  Avg. 30 Year Fixed Mortgage Rate  Avg. 15 Year Fixed Mortgage Rate  \
# 0   1963                               NaN                               NaN
# 1   1964                               NaN                               NaN
# 2   1965                               NaN                               NaN
# 3   1966                               NaN                               NaN
# 4   1967                               NaN                               NaN
# ..   ...                               ...                               ...
# 56  2019                              3.94                              3.39
# 57  2020                              3.11                              2.60
# 58  2021                              2.96                              2.27
# 59  2022                              5.34                              4.58
# 60  2023                              6.79                              6.09
#
# ...

# %%
#Plotting the avg. 30 year mortgage rate against the avg. employment rate over time
y_values1 = fred_data['Avg. 30 Year Fixed Mortgage Rate']
y_values2 = fred_data['Avg. Unemployment Rate']
years = fred_data['Year']
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(years, y_values1, label='Mortgage Rate', color='orange')
ax1.set_ylabel('Mortgage Rate', color='orange')
ax1.set_xlabel('Year')
ax1.tick_params('y')
ax2 = ax1.twinx()
ax2.plot(years, y_values2, label='Unemployment Rate', color='blue')
ax2.set_ylabel('Unemployment Rate', color='blue')
ax2.set_xlabel('Year')
ax2.tick_params('x')
ax1.legend()
ax2.legend()
plt.title('Avg. 30 Year Fixed Mortgage Rate vs. Avg. Unemployment Rate')
plt.show()

# %%
#Plotting the avg. 30 year mortgage rate against the avg. Consumer Price Index
y_values1 = fred_data['Avg. 30 Year Fixed Mortgage Rate']
y_values3 = fred_data['Avg. CPI']
years = fred_data['Year']
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(years, y_values1, label='Mortgage Rate', color='green')
ax1.set_ylabel('Mortgage Rate', color='green')
ax1.set_xlabel('Year')
ax1.tick_params('y')
ax2 = ax1.twinx()
ax2.plot(years, y_values3, label='Avg. CPI', color='purple')
ax2.set_ylabel('Avg. CPI', color='purple')
ax2.set_xlabel('Year')
ax2.tick_params('x')
ax1.legend()
ax2.legend()
plt.title('Avg. 30 Year Fixed Mortgage Rate vs. Avg. Consumer Price Index')
plt.show()

# %%
#Plotting the avg. 30 year mortgage rate against the Avg. Household Debt to GDP
y_values1 = fred_data['Avg. 30 Year Fixed Mortgage Rate']
y_values3 = fred_data['Avg. Household Debt to GDP']
years = fred_data['Year']
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(years, y_values1, label='Mortgage Rate', color='green')
ax1.set_ylabel('Mortgage Rate', color='green')
ax1.set_xlabel('Year')
ax1.tick_params('y')
ax2 = ax1.twinx()
ax2.plot(years, y_values3, label='Avg. Household Debt to GDP', color='red')
ax2.set_ylabel('Avg. Household Debt to GDP', color='red')
ax2.set_xlabel('Year')
ax2.tick_params('x')
ax1.legend()
ax2.legend()
plt.title('Avg. 30 Year Fixed Mortgage Rate vs. Avg. Household Debt to GDP')
plt.show()

# %%
#Plotting the avg. 30 year mortgage rate against the Avg. GDP (Billions of $)
y_values1 = fred_data['Avg. 30 Year Fixed Mortgage Rate']
y_values3 = fred_data['Avg. GDP (Billions of $)']
years = fred_data['Year']
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(years, y_values1, label='Mortgage Rate', color='green')
ax1.set_ylabel('Mortgage Rate', color='green')
ax1.set_xlabel('Year')
ax1.tick_params('y')
ax2 = ax1.twinx()
ax2.plot(years, y_values3, label='Avg. GDP (Billions of $)', color='maroon')
ax2.set_ylabel('Avg. GDP (Billions of $)', color='maroon')
ax2.set_xlabel('Year')
ax2.tick_params('x')
ax1.legend()
ax2.legend()
plt.title('Avg. 30 Year Fixed Mortgage Rate vs. Avg. GDP (Billions of $)')
plt.show()

# %%
#Plotting the avg. 30 year mortgage rate against the Avg. Inflation Rate
y_values1 = fred_data['Avg. 30 Year Fixed Mortgage Rate']
y_values4 = fred_data['Avg. Inflation Rate']
years = fred_data['Year']
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(years, y_values1, label='Mortgage Rate', color='green')
ax1.set_ylabel('Mortgage Rate', color='green')
ax1.set_xlabel('Year')
ax1.tick_params('y')
ax2 = ax1.twinx()
ax2.plot(years, y_values4, label='Avg. Inflation Rate', color='blue')
ax2.set_ylabel('Avg. Inflation Rate', color='blue')
ax2.set_xlabel('Year')
ax2.tick_params('x')
ax1.legend(loc="upper right")
ax2.legend(loc="upper left")
plt.title('Avg. 30 Year Fixed Mortgage Rate vs. Avg. Inflation Rate')
plt.show()
