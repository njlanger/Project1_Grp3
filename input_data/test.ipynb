# %%
#Import dependencies
import requests
import json
import pandas as pd
from pprint import pprint
API_KEY = "51b260c46d67b499bbb3febc8d423f76"

# %% [markdown]
# # Searching without using Fred-full Library

# %%
url = "https://api.stlouisfed.org/fred/series"
params = {
    "api_key": API_KEY,
    "file_type": "json",
    "series_id": "MSPUS"
}
response = requests.get(url=url, params=params)
response.status_code
data = response.json()
data
# Out:
# {'realtime_start': '2023-11-09',
#  'realtime_end': '2023-11-09',
#  'seriess': [{'id': 'MSPUS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price of Houses Sold for the United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:02-05',
#    'popularity': 90}]}

# %%
# !pip install full-fred
# Out:
# Requirement already satisfied: full-fred in /Users/justinblake/anaconda3/lib/python3.11/site-packages (0.0.9a3)
# Requirement already satisfied: pandas in /Users/justinblake/anaconda3/lib/python3.11/site-packages (from full-fred) (1.5.3)
# Requirement already satisfied: requests in /Users/justinblake/anaconda3/lib/python3.11/site-packages (from full-fred) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/justinblake/anaconda3/lib/python3.11/site-packages (from pandas->full-fred) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/justinblake/anaconda3/lib/python3.11/site-packages (from pandas->full-fred) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/justinblake/anaconda3/lib/python3.11/site-packages (from pandas->full-fred) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/justinblake/anaconda3/lib/python3.11/site-packages (from requests->full-fred) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/justinblake/anaconda3/lib/python3.11/site-packages (from requests->full-fred) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/justinblake/anaconda3/lib/python3.11/site-packages (from requests->full-fred) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/justinblake/anaconda3/lib/python3.11/site-packages (from requests->full-fred) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /Users/justinblake/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->full-fred) (1.16.0)

# %% [markdown]
# # Searching for Series using Full Fred library

# %%
from full_fred.fred import Fred
fred = Fred('api_key.txt')

fred.get_api_key_file()
# Out:
# 'api_key.txt'

# %%
# Search through Fred database for series
fred.search_for_series(search_words=["home sales"])

# Grab the 'id' value for the series you want
# For example - if we want the id from the first dataset
#id = 'MSPUS'
# Out:
# {'realtime_start': '2023-11-09',
#  'realtime_end': '2023-11-09',
#  'order_by': 'search_rank',
#  'sort_order': 'desc',
#  'count': 4034,
#  'offset': 0,
#  'limit': 1000,
#  'seriess': [{'id': 'MSPUS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price of Houses Sold for the United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:02-05',
#    'popularity': 90,
#    'group_popularity': 89},
#   {'id': 'ASPUS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Average Sales Price of Houses Sold for the United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:03-05',
#    'popularity': 84,
#    'group_popularity': 84},
#   {'id': 'EXHOSLUSM495S',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Existing Home Sales',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Number of Units',
#    'units_short': 'Number of Units',
#    'seasonal_adjustment': 'Seasonally Adjusted Annual Rate',
#    'seasonal_adjustment_short': 'SAAR',
#    'last_updated': '2023-10-19 09:16:00-05',
#    'popularity': 75,
#    'group_popularity': 75,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nExisting-home sales measures the transaction volume of existing single-family homes, condos, and co-ops.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'EXHOSLUSM495N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Existing Home Sales',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Number of Units',
#    'units_short': 'Number of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-19 09:15:58-05',
#    'popularity': 45,
#    'group_popularity': 75,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nExisting-home sales measures the transaction volume of existing single-family homes, condos, and co-ops.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'HSN1F',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New One Family Houses Sold: United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Thousands',
#    'units_short': 'Thous.',
#    'seasonal_adjustment': 'Seasonally Adjusted Annual Rate',
#    'seasonal_adjustment_short': 'SAAR',
#    'last_updated': '2023-10-25 09:01:05-05',
#    'popularity': 70,
#    'group_popularity': 70},
#   {'id': 'HOSINVUSM495N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Existing Home Sales: Housing Inventory',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Number of Units',
#    'units_short': 'Number of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-19 09:15:54-05',
#    'popularity': 67,
#    'group_popularity': 67,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\r\n\r\nInventory indicates the number of properties marked as "active" on the market or those pending sales. When a seller lists a property, it becomes counted as inventory.\r\n\r\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\r\n\r\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'HSN1FNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New One Family Houses Sold: United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:10-05',
#    'popularity': 36,
#    'group_popularity': 70},
#   {'id': 'HSN1FA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New One Family Houses Sold: United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-02-24 09:01:11-06',
#    'popularity': 9,
#    'group_popularity': 70},
#   {'id': 'MSPNHSUS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price for New Houses Sold in the United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:07-05',
#    'popularity': 65,
#    'group_popularity': 65},
#   {'id': 'HOSMEDUSM052N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price of Existing Homes',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-19 09:15:58-05',
#    'popularity': 62,
#    'group_popularity': 62,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nThe median sales price measures the price at which half of existing homes sold for more and half sold for less.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'HOSSUPUSM673N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Existing Home Sales: Months Supply',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': "Months' Supply",
#    'units_short': "Months' Supply",
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-19 09:15:58-05',
#    'popularity': 61,
#    'group_popularity': 61,
#    'notes': "The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nMonths' supply refers to the number of months it would take for the current inventory of homes on the market to sell given the current sales pace.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission."},
#   {'id': 'MSPNHSUSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price for New Houses Sold in the United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-04-25 09:02:25-05',
#    'popularity': 9,
#    'group_popularity': 65},
#   {'id': 'EXSFHSUSM495S',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Existing Single-Family Home Sales',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Number of Units',
#    'units_short': 'Number of Units',
#    'seasonal_adjustment': 'Seasonally Adjusted Annual Rate',
#    'seasonal_adjustment_short': 'SAAR',
#    'last_updated': '2023-10-19 09:15:54-05',
#    'popularity': 50,
#    'group_popularity': 51,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nExisting-home sales measures the transaction volume of existing single-family homes, condos, and co-ops.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'HSFMEDUSM052N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price of Existing Single-Family Homes',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-19 09:15:57-05',
#    'popularity': 50,
#    'group_popularity': 50,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nThe median sales price measures the price at which half of existing homes sold for more and half sold for less.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'EXSFHSUSM495N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Existing Single-Family Home Sales',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Number of Units',
#    'units_short': 'Number of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-19 09:15:59-05',
#    'popularity': 7,
#    'group_popularity': 51,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nExisting-home sales measures the transaction volume of existing single-family homes, condos, and co-ops.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'RSFHFS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Advance Retail Sales: Furniture and Home Furnishings Stores',
#    'observation_start': '1992-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Millions of Dollars',
#    'units_short': 'Mil. of $',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-17 07:34:05-05',
#    'popularity': 45,
#    'group_popularity': 47,
#    'notes': 'The value for the most recent month is an advance estimate that is based on data from a subsample of firms from the larger Monthly Retail Trade Survey. The advance estimate will be superseded in following months by revised estimates derived from the larger Monthly Retail Trade Survey. The associated series from the Monthly Retail Trade Survey is available at https://fred.stlouisfed.org/series/MRTSSM442USS\n\n Information about the Advance Monthly Retail Sales Survey can be found on the Census website at https://www.census.gov/retail/marts/about_the_surveys.html'},
#   {'id': 'HNFSEPUSSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New One Family Homes for Sale in the United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly, End of Month',
#    'frequency_short': 'M',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-25 09:01:08-05',
#    'popularity': 44,
#    'group_popularity': 44},
#   {'id': 'ASPNHSUS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Average Sales Price for New Houses Sold in the United States',
#    'observation_start': '1975-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:08-05',
#    'popularity': 45,
#    'group_popularity': 46},
#   {'id': 'HSFINVUSM495N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Existing Single-Family Home Sales: Housing Inventory',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Number of Units',
#    'units_short': 'Number of Units',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-19 09:16:00-05',
#    'popularity': 43,
#    'group_popularity': 43,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nInventory indicates the number of properties marked as "active" on the market or those pending sales. When a seller lists a property, it becomes counted as inventory.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'RSFHFSN',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Advance Retail Sales: Furniture and Home Furnishings Stores',
#    'observation_start': '1992-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Millions of Dollars',
#    'units_short': 'Mil. of $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-17 07:34:11-05',
#    'popularity': 12,
#    'group_popularity': 47,
#    'notes': 'The value for the most recent month is an advance estimate that is based on data from a subsample of firms from the larger Monthly Retail Trade Survey. The advance estimate will be superseded in following months by revised estimates derived from the larger Monthly Retail Trade Survey. The associated series from the Monthly Retail Trade Survey is available at https://fred.stlouisfed.org/series/MRTSSM442USN\n\n Information about the Advance Monthly Retail Sales Survey can be found on the Census website at https://www.census.gov/retail/marts/about_the_surveys.html'},
#   {'id': 'MARTSMPCSM442USS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Advance Retail Sales: Furniture and Home Furnishings Stores',
#    'observation_start': '1992-02-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Percent Change from Preceding Period',
#    'units_short': '% Chg. from Preceding Period',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-17 07:34:13-05',
#    'popularity': 4,
#    'group_popularity': 47,
#    'notes': 'The value for the most recent month is an advance estimate that is based on data from a subsample of firms from the larger Monthly Retail Trade Survey. The advance estimate will be superseded in following months by revised estimates derived from the larger Monthly Retail Trade Survey. The associated series from the Monthly Retail Trade Survey is available at https://fred.stlouisfed.org/series/MRTSMPCSM442USS\n\n Information about the Advance Monthly Retail Sales Survey can be found on the Census website at https://www.census.gov/retail/marts/about_the_surveys.html'},
#   {'id': 'MARTSMPCSM442USN',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Advance Retail Sales: Furniture and Home Furnishings Stores',
#    'observation_start': '1992-02-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Percent Change from Preceding Period',
#    'units_short': '% Chg. from Preceding Period',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-17 07:34:16-05',
#    'popularity': 1,
#    'group_popularity': 47,
#    'notes': 'The value for the most recent month is an advance estimate that is based on data from a subsample of firms from the larger Monthly Retail Trade Survey. The advance estimate will be superseded in following months by revised estimates derived from the larger Monthly Retail Trade Survey. The associated series from the Monthly Retail Trade Survey is available at https://fred.stlouisfed.org/series/MRTSMPCSM442USN\n\n Information about the Advance Monthly Retail Sales Survey can be found on the Census website at https://www.census.gov/retail/marts/about_the_surveys.html'},
#   {'id': 'SPSNSAUS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Average Sales Price of New Manufactured Homes: Single Homes in the United States',
#    'observation_start': '2014-01-01',
#    'observation_end': '2023-06-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'U.S. Dollars',
#    'units_short': 'U.S. $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-11-06 11:18:01-06',
#    'popularity': 42,
#    'group_popularity': 42},
#   {'id': 'ASPNHSUSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Average Sales Price for New Houses Sold in the United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-04-25 09:02:29-05',
#    'popularity': 5,
#    'group_popularity': 46},
#   {'id': 'MSPNE',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price of Houses Sold for the Northeast Census Region',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:09-05',
#    'popularity': 43,
#    'group_popularity': 43},
#   {'id': 'HSFSUPUSM673N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Existing Single-Family Home Sales: Months Supply',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': "Months' Supply",
#    'units_short': "Months' Supply",
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-19 09:15:59-05',
#    'popularity': 39,
#    'group_popularity': 39,
#    'notes': "The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nMonths' supply refers to the number of months it would take for the current inventory of homes on the market to sell given the current sales pace.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission."},
#   {'id': 'MRTSSM442USN',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Retail Sales: Furniture and Home Furnishings Stores',
#    'observation_start': '1992-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Millions of Dollars',
#    'units_short': 'Mil. of $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-17 09:08:07-05',
#    'popularity': 32,
#    'group_popularity': 38},
#   {'id': 'MRTSSM442USS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Retail Sales: Furniture and Home Furnishings Stores',
#    'observation_start': '1992-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Millions of Dollars',
#    'units_short': 'Mil. of $',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-17 09:08:09-05',
#    'popularity': 20,
#    'group_popularity': 38,
#    'notes': "The most recent month's value of the advance estimate based on data from a subsample of firms from the larger Monthly Retail Trade Survey is available at https://fred.stlouisfed.org/series/RSFHFS\n\n Information about the Monthly Retail Trade Survey can be found on the Census website at https://www.census.gov/retail/mrts/about_the_surveys.html"},
#   {'id': 'MRTSMPCSM442USS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Retail Sales: Furniture and Home Furnishings Stores',
#    'observation_start': '1992-02-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Percent Change from Preceding Period',
#    'units_short': '% Chg. from Preceding Period',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-17 09:08:37-05',
#    'popularity': 1,
#    'group_popularity': 38},
#   {'id': 'MRTSMPCSM442USN',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Retail Sales: Furniture and Home Furnishings Stores',
#    'observation_start': '1992-02-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Percent Change from Preceding Period',
#    'units_short': '% Chg. from Preceding Period',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-17 09:08:37-05',
#    'popularity': 1,
#    'group_popularity': 38,
#    'notes': "The most recent month's value of the advance estimate based on data from a subsample of firms from the larger Monthly Retail Trade Survey is available at https://fred.stlouisfed.org/series/MARTSMPCSM442USN\n\n Information about the Monthly Retail Trade Survey can be found on the Census website at https://www.census.gov/retail/mrts/about_the_surveys.html"},
#   {'id': 'MSPS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price of Houses Sold for the South Census Region',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:09-05',
#    'popularity': 36,
#    'group_popularity': 36},
#   {'id': 'MSPW',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price of Houses Sold for the West Census Region',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:09-05',
#    'popularity': 36,
#    'group_popularity': 36},
#   {'id': 'HSTFC',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Houses Sold by Type of Financing, Cash Purchase',
#    'observation_start': '1988-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:09-05',
#    'popularity': 35,
#    'group_popularity': 35},
#   {'id': 'MSPMW',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price of Houses Sold for the Midwest Census Region',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:09-05',
#    'popularity': 33,
#    'group_popularity': 33},
#   {'id': 'NHFSEPCS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses for Sale by Stage of Construction, Completed',
#    'observation_start': '1999-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-25 09:01:10-05',
#    'popularity': 28,
#    'group_popularity': 29},
#   {'id': 'SPTNSAWE',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Average Sales Price of New Manufactured Homes: Total Homes in West Census Region',
#    'observation_start': '2014-01-01',
#    'observation_end': '2023-06-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'U.S. Dollars',
#    'units_short': 'U.S. $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-11-06 11:18:02-06',
#    'popularity': 26,
#    'group_popularity': 26},
#   {'id': 'NHSUSSPT',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses Sold by Sales Price in the United States, Total',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:11-05',
#    'popularity': 28,
#    'group_popularity': 28},
#   {'id': 'NHFSEPC',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses for Sale by Stage of Construction, Completed',
#    'observation_start': '1973-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly, End of Month',
#    'frequency_short': 'M',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:13-05',
#    'popularity': 5,
#    'group_popularity': 29},
#   {'id': 'NHFSEPCA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses for Sale by Stage of Construction, Completed',
#    'observation_start': '1973-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-04-25 09:02:45-05',
#    'popularity': 1,
#    'group_popularity': 29},
#   {'id': 'NHSUSSPTP',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses Sold by Sales Price in the United States, Total',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Percent',
#    'units_short': '%',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:18-05',
#    'popularity': 2,
#    'group_popularity': 28,
#    'notes': 'Percents computed from unrounded figures. Components may not add to total because of rounding.'},
#   {'id': 'NHSUSSPTQP',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses Sold by Sales Price in the United States, Total',
#    'observation_start': '2002-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Percent',
#    'units_short': '%',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:22-05',
#    'popularity': 1,
#    'group_popularity': 28,
#    'notes': 'Percents computed from unrounded figures. Components may not add to total because of rounding.'},
#   {'id': 'NHSUSSPTAP',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses Sold by Sales Price in the United States, Total',
#    'observation_start': '2002-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Percent',
#    'units_short': '%',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-01-26 09:01:43-06',
#    'popularity': 1,
#    'group_popularity': 28,
#    'notes': 'Percents computed from unrounded figures. Components may not add to total because of rounding.'},
#   {'id': 'NHSUSSPTA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses Sold by Sales Price in the United States, Total',
#    'observation_start': '2002-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-04-25 09:03:04-05',
#    'popularity': 1,
#    'group_popularity': 28},
#   {'id': 'MNMFS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Number of Months on Sales Market for Newly Completed Homes',
#    'observation_start': '1975-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Months',
#    'units_short': 'Months',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:11-05',
#    'popularity': 23,
#    'group_popularity': 23,
#    'notes': 'This is the median number of months for sale since the completion of the home.'},
#   {'id': 'ESALEUSQ176N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Housing Inventory Estimate: Vacant Housing Units for Sale in the United States',
#    'observation_start': '2000-04-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-31 09:32:06-05',
#    'popularity': 25,
#    'group_popularity': 25,
#    'notes': 'This group is limited to units for sale only; it excludes units both for rent and sale. If a unit was located in a multi-unit structure which was for sale as an entire structure and if the unit was not for rent, it was reported as "held off market." However, if the individual unit was intended to be occupied by the new owner, it was reported as "for sale."'},
#   {'id': 'HNFSUSNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New One Family Houses for Sale in the United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly, End of Month',
#    'frequency_short': 'M',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:11-05',
#    'popularity': 25,
#    'group_popularity': 25},
#   {'id': 'MNMFSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Number of Months on Sales Market for Newly Completed Homes',
#    'observation_start': '1988-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-03-23 10:21:18-05',
#    'popularity': 1,
#    'group_popularity': 23},
#   {'id': 'HNFSUSNSAA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New One Family Houses for Sale in the United States',
#    'observation_start': '1963-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-03-23 10:21:15-05',
#    'popularity': 1,
#    'group_popularity': 25},
#   {'id': 'HOSMEDUSMWM052N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Median Sales Price of Existing Homes in Midwest Census Region',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-19 09:15:56-05',
#    'popularity': 21,
#    'group_popularity': 21,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nThe median sales price measures the price at which half of existing homes sold for more and half sold for less.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'MRTSSM4541USS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Retail Sales: Electronic Shopping and Mail-Order Houses',
#    'observation_start': '1992-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Millions of Dollars',
#    'units_short': 'Mil. of $',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-17 09:08:08-05',
#    'popularity': 19,
#    'group_popularity': 23,
#    'notes': 'Information about the Monthly Retail Trade Survey can be found on the Census website at https://www.census.gov/retail/mrts/about_the_surveys.html'},
#   {'id': 'MRTSSM4541USN',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Retail Sales: Electronic Shopping and Mail-Order Houses',
#    'observation_start': '1992-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Millions of Dollars',
#    'units_short': 'Mil. of $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-17 09:08:25-05',
#    'popularity': 8,
#    'group_popularity': 23},
#   {'id': 'NHFSEPUCS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses for Sale by Stage of Construction, Under Construction',
#    'observation_start': '1999-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-25 09:01:11-05',
#    'popularity': 17,
#    'group_popularity': 18},
#   {'id': 'NHFSEPUC',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses for Sale by Stage of Construction, Under Construction',
#    'observation_start': '1973-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly, End of Month',
#    'frequency_short': 'M',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:16-05',
#    'popularity': 3,
#    'group_popularity': 18},
#   {'id': 'NHFSEPUCA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses for Sale by Stage of Construction, Under Construction',
#    'observation_start': '1973-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-04-25 09:02:52-05',
#    'popularity': 1,
#    'group_popularity': 18},
#   {'id': 'HOUSTPFST1FQ',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Privately Owned Housing Starts in the United States by Purpose of Construction, Built for Sale Total One-Family Units',
#    'observation_start': '1974-01-01',
#    'observation_end': '2023-04-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-08-16 07:46:02-05',
#    'popularity': 17,
#    'group_popularity': 17},
#   {'id': 'ASPNE',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Average Sales Price of Houses Sold for the Northeast Census Region',
#    'observation_start': '1975-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:12-05',
#    'popularity': 16,
#    'group_popularity': 16},
#   {'id': 'ASPMW',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Average Sales Price of Houses Sold for the Midwest Census Region',
#    'observation_start': '1975-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:12-05',
#    'popularity': 16,
#    'group_popularity': 16},
#   {'id': 'EXHOSLUSNEM495S',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Existing Home Sales in Northeast Census Region',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Number of Units',
#    'units_short': 'Number of Units',
#    'seasonal_adjustment': 'Seasonally Adjusted Annual Rate',
#    'seasonal_adjustment_short': 'SAAR',
#    'last_updated': '2023-10-19 09:15:56-05',
#    'popularity': 13,
#    'group_popularity': 13,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nExisting-home sales measures the transaction volume of existing single-family homes, condos, and co-ops.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'NHSDPTS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses Sold by Stage of Construction, Total',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Seasonally Adjusted Annual Rate',
#    'seasonal_adjustment_short': 'SAAR',
#    'last_updated': '2023-10-25 09:01:12-05',
#    'popularity': 14,
#    'group_popularity': 15},
#   {'id': 'EXHOSLUSNEM495N',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Existing Home Sales in Northeast Census Region',
#    'observation_start': '2022-09-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Number of Units',
#    'units_short': 'Number of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-19 09:15:59-05',
#    'popularity': 2,
#    'group_popularity': 13,
#    'notes': 'The National Association of Realtors monthly housing indicators are based on a representative sample of local boards and multiple listing services. Sales volume, inventory, and price levels for existing homes are measured for the US in aggregate and by census region. Existing homes, unlike new homes, are homes that are owned and occupied before coming onto the market.\n\nExisting-home sales measures the transaction volume of existing single-family homes, condos, and co-ops.\n\nFor more information, see Methodology: Existing-Home Sales (https://www.nar.realtor/research-and-statistics/housing-statistics/existing-home-sales/methodology).\n\nCopyright, 2016, National Association of Realtors. Reprinted with permission.'},
#   {'id': 'NHSDPT',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses Sold by Stage of Construction, Total',
#    'observation_start': '1963-01-01',
#    'observation_end': '2023-09-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:21-05',
#    'popularity': 1,
#    'group_popularity': 15},
#   {'id': 'NHSDPTA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'New Houses Sold by Stage of Construction, Total',
#    'observation_start': '1963-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Thousands of Units',
#    'units_short': 'Thous. of Units',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-02-24 09:01:15-06',
#    'popularity': 1,
#    'group_popularity': 15},
#   {'id': 'ASPS',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Average Sales Price of Houses Sold for the South Census Region',
#    'observation_start': '1975-01-01',
#    'observation_end': '2023-07-01',
#    'frequency': 'Quarterly',
#    'frequency_short': 'Q',
#    'units': 'Dollars',
#    'units_short': '$',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-25 09:01:12-05',
#    'popularity': 14,
# ...
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-31 08:11:40-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'ATXRLTNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for Atlanta, Georgia',
#    'observation_start': '1991-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-31 08:11:39-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'BOXRLTSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for Boston, Massachusetts',
#    'observation_start': '1987-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-31 08:11:41-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'BOXRLTNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for Boston, Massachusetts',
#    'observation_start': '1987-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-31 08:11:41-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'LVXRLTSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for Las Vegas, Nevada',
#    'observation_start': '1993-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-31 08:11:50-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'LVXRLTNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for Las Vegas, Nevada',
#    'observation_start': '1993-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-31 08:11:49-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'WDXRLTSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for Washington D.C.',
#    'observation_start': '1987-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-31 08:11:37-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'WDXRLTNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for Washington D.C.',
#    'observation_start': '1987-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-31 08:11:36-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'MIXRLTSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for Miami, Florida',
#    'observation_start': '1987-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-31 08:11:55-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'MIXRLTNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for Miami, Florida',
#    'observation_start': '1987-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-31 08:11:54-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'NYXRLTSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for New York, New York',
#    'observation_start': '1987-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-31 08:12:00-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'NYXRLTNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for New York, New York',
#    'observation_start': '1987-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-31 08:11:59-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'LVXRMTSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Middle Tier) for Las Vegas, Nevada',
#    'observation_start': '1993-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-31 08:11:51-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'LVXRMTNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Middle Tier) for Las Vegas, Nevada',
#    'observation_start': '1993-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-31 08:11:50-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'MNXRMTSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Middle Tier) for Minneapolis, Minnesota',
#    'observation_start': '1989-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-31 08:11:58-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'MNXRMTNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Middle Tier) for Minneapolis, Minnesota',
#    'observation_start': '1989-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-31 08:11:58-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'SDXRLTSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for San Diego, California',
#    'observation_start': '1989-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2023-10-31 08:12:15-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."},
#   {'id': 'SDXRLTNSA',
#    'realtime_start': '2023-11-09',
#    'realtime_end': '2023-11-09',
#    'title': 'Home Price Index (Low Tier) for San Diego, California',
#    'observation_start': '1989-01-01',
#    'observation_end': '2023-08-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index Jan 2000=100',
#    'units_short': 'Index Jan 2000=100',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-10-31 08:12:15-05',
#    'popularity': 1,
#    'group_popularity': 1,
#    'notes': "For more information regarding the index, please visit Standard & Poor's (https://www.spglobal.com/spdji/en/documents/methodologies/methodology-sp-corelogic-cs-home-price-indices.pdf). There is more information about home price sales pairs in the Methodology section. Copyright, 2016, Standard & Poor's Financial Services LLC. Reprinted with permission."}]}

# %%
# Use the .get_series_df method and input the 'id' from the desired dataset
median_home_price = fred.get_series_df('MSPUS')
median_home_price
# Out:
#     realtime_start realtime_end        date     value
# 0       2023-11-09   2023-11-09  1963-01-01     17800
# 1       2023-11-09   2023-11-09  1963-04-01     18000
# 2       2023-11-09   2023-11-09  1963-07-01     17900
# 3       2023-11-09   2023-11-09  1963-10-01     18500
# 4       2023-11-09   2023-11-09  1964-01-01     18500
# ..             ...          ...         ...       ...
# 238     2023-11-09   2023-11-09  2022-07-01  468000.0
# 239     2023-11-09   2023-11-09  2022-10-01  479500.0
# 240     2023-11-09   2023-11-09  2023-01-01  429000.0
# 241     2023-11-09   2023-11-09  2023-04-01  418500.0
# 242     2023-11-09   2023-11-09  2023-07-01  431000.0
#
# [243 rows x 4 columns]

# %%
interest_rate_search = fred.search_for_series(search_words=["interest rate"])

# %%
mortgage_30 = fred.get_series_df("MORTGAGE30US")
mortgage_30

#Data sourced from '30-Year Fixed Rate Mortgage Average in the United States'
# Out:
#      realtime_start realtime_end        date value
# 0        2023-11-09   2023-11-09  1971-04-02  7.33
# 1        2023-11-09   2023-11-09  1971-04-09  7.31
# 2        2023-11-09   2023-11-09  1971-04-16  7.31
# 3        2023-11-09   2023-11-09  1971-04-23  7.31
# 4        2023-11-09   2023-11-09  1971-04-30  7.29
# ...             ...          ...         ...   ...
# 2741     2023-11-09   2023-11-09  2023-10-12  7.57
# 2742     2023-11-09   2023-11-09  2023-10-19  7.63
# 2743     2023-11-09   2023-11-09  2023-10-26  7.79
# 2744     2023-11-09   2023-11-09  2023-11-02  7.76
# 2745     2023-11-09   2023-11-09  2023-11-09   7.5
#
# [2746 rows x 4 columns]

# %%
mortgage_15 = fred.get_series_df("MORTGAGE15US")
mortgage_15
#Data sourced from '15-Year Fixed Rate Mortgage Average in the United States'
# Out:
#      realtime_start realtime_end        date value
# 0        2023-11-09   2023-11-09  1991-08-30  8.77
# 1        2023-11-09   2023-11-09  1991-09-06  8.79
# 2        2023-11-09   2023-11-09  1991-09-13  8.68
# 3        2023-11-09   2023-11-09  1991-09-20  8.62
# 4        2023-11-09   2023-11-09  1991-09-27  8.59
# ...             ...          ...         ...   ...
# 1676     2023-11-09   2023-11-09  2023-10-12  6.89
# 1677     2023-11-09   2023-11-09  2023-10-19  6.92
# 1678     2023-11-09   2023-11-09  2023-10-26  7.03
# 1679     2023-11-09   2023-11-09  2023-11-02  7.03
# 1680     2023-11-09   2023-11-09  2023-11-09  6.81
#
# [1681 rows x 4 columns]

# %%
home_price_search = fred.search_for_series(search_words=["home price"])

# %%
home_price_index = fred.get_series_df("CSUSHPINSA")
home_price_index

#Dataframe sourced from S&P/Case-Shiller U.S. National Home Price Index
# Out:
#     realtime_start realtime_end        date               value
# 0       2023-11-09   2023-11-09  1975-01-01                   .
# 1       2023-11-09   2023-11-09  1975-02-01                   .
# 2       2023-11-09   2023-11-09  1975-03-01                   .
# 3       2023-11-09   2023-11-09  1975-04-01                   .
# 4       2023-11-09   2023-11-09  1975-05-01                   .
# ..             ...          ...         ...                 ...
# 579     2023-11-09   2023-11-09  2023-04-01             301.469
# 580     2023-11-09   2023-11-09  2023-05-01             305.427
# 581     2023-11-09   2023-11-09  2023-06-01             308.307
# 582     2023-11-09   2023-11-09  2023-07-01  310.16200000000003
# 583     2023-11-09   2023-11-09  2023-08-01             311.499
#
# [584 rows x 4 columns]

# %%
gdp_search = fred.search_for_series(search_words=["GDP"])

# %%
household_debt_to_gdp = fred.get_series_df("HDTGPDUSQ163N")
household_debt_to_gdp
# Out:
#    realtime_start realtime_end        date             value
# 0      2023-11-09   2023-11-09  2005-01-01  86.7953478741027
# 1      2023-11-09   2023-11-09  2005-04-01  89.3665332228971
# 2      2023-11-09   2023-11-09  2005-07-01  92.1382753543162
# 3      2023-11-09   2023-11-09  2005-10-01  94.4367215780109
# 4      2023-11-09   2023-11-09  2006-01-01  91.7366889603057
# ..            ...          ...         ...               ...
# 69     2023-11-09   2023-11-09  2022-04-01  76.1400500108485
# 70     2023-11-09   2023-11-09  2022-07-01  77.4079771917544
# 71     2023-11-09   2023-11-09  2022-10-01  78.2792851609939
# 72     2023-11-09   2023-11-09  2023-01-01    74.35503339374
# 73     2023-11-09   2023-11-09  2023-04-01  74.9875805431543
#
# [74 rows x 4 columns]
