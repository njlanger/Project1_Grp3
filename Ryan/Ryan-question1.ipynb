# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from math import floor
from pprint import pprint

# %%
fred_file = Path("../output_data/fred_data.csv")
fred_data = pd.read_csv(fred_file)
fred_data
# Out:
#     Year  Avg. 30 Year Fixed Mortgage Rate  Avg. 15 Year Fixed Mortgage Rate  \
# 0   1963                               NaN                               NaN
# 1   1964                               NaN                               NaN
# 2   1965                               NaN                               NaN
# 3   1966                               NaN                               NaN
# 4   1967                               NaN                               NaN
# ..   ...                               ...                               ...
# 56  2019                              3.94                              3.39
# 57  2020                              3.11                              2.60
# 58  2021                              2.96                              2.27
# 59  2022                              5.34                              4.58
# 60  2023                              6.77                              6.07
#
# ...

# %%
#Plotting the avg. 30 year mortgage rate against the avg. employment rate over time
y_values1 = fred_data['Avg. 30 Year Fixed Mortgage Rate']
y_values2 = fred_data['Avg. Unemployment Rate']
years = fred_data['Year']
plt.plot(years, y_values1, label='Mortgage Rate')
plt.plot(years, y_values2, label='Unemployment Rate')
plt.legend()
plt.title('Avg. 30 Year Fixed Mortgage Rate vs. Avg. Unemployment Rate')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.show()

# %%
#Plotting the avg. 15 year mortgage rate against the avg. employment rate over time
y_values1 = fred_data['Avg. 15 Year Fixed Mortgage Rate']
y_values2 = fred_data['Avg. Unemployment Rate']
years = fred_data['Year']
plt.plot(years, y_values1, label='Mortgage Rate')
plt.plot(years, y_values2, label='Unemployment Rate')
plt.legend()
plt.title('Avg. 15 Year Fixed Mortgage Rate vs. Avg. Unemployment Rate')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.show()

# %%
#Plotting the avg. 30 year mortgage rate against the avg. Consumer Price Index
y_values1 = fred_data['Avg. 30 Year Fixed Mortgage Rate']
y_values2 = fred_data['Avg. CPI']
years = fred_data['Year']
plt.plot(years, y_values1, label='Mortgage Rate')
plt.plot(years, y_values2, label='CPI')
plt.legend()
plt.title('Avg. 30 Year Fixed Mortgage Rate vs. Avg. Consumer Price Index')
plt.xlabel('Year')
plt.show()
#NEED A MULTIPLIER FOR INFLATION TO COMPARE ACCURATELY

# %%
#Plotting the avg. 15 year mortgage rate against the avg. Consumer Price Index
y_values1 = fred_data['Avg. 15 Year Fixed Mortgage Rate']
y_values2 = fred_data['Avg. CPI']
years = fred_data['Year']
plt.plot(years, y_values1, label='Mortgage Rate')
plt.plot(years, y_values2, label='CPI')
plt.legend()
plt.title('Avg. 15 Year Fixed Mortgage Rate vs. Avg. Consumer Price Index')
plt.xlabel('Year')
plt.show()
#NEED A MULTIPLIER FOR INFLATION TO COMPARE ACCURATELY

# %%
#Plotting the avg. 30 year mortgage rate against the Avg. Household Debt to GDP
y_values1 = fred_data['Avg. 30 Year Fixed Mortgage Rate']
y_values2 = fred_data['Avg. Household Debt to GDP']
years = fred_data['Year']
plt.plot(years, y_values1, label='Mortgage Rate')
plt.plot(years, y_values2, label='Debt/GDP Ratio')
plt.legend()
plt.title('Avg. 30 Year Fixed Mortgage Rate vs. Avg. Household Debt to GDP')
plt.xlabel('Year')
plt.show()
#Stick to GDP only!

# %%
#Plotting the avg. 15 year mortgage rate against the Avg. Household Debt to GDP
y_values1 = fred_data['Avg. 15 Year Fixed Mortgage Rate']
y_values2 = fred_data['Avg. Household Debt to GDP']
years = fred_data['Year']
plt.plot(years, y_values1, label='Mortgage Rate')
plt.plot(years, y_values2, label='Debt/GDP Ratio')
plt.legend()
plt.title('Avg. 15 Year Fixed Mortgage Rate vs. Avg. Household Debt to GDP')
plt.xlabel('Year')
plt.show()
#Stick to GDP only!
